# %%
#https://stackoverflow.com/questions/41648129/balancing-an-imbalanced-dataset-with-keras-image-generator
#https://iq.opengenus.org/architecture-of-densenet121/
#https://www.pluralsight.com/guides/introduction-to-densenet-with-tensorflow
#https://www.kaggle.com/code/ahmadjaved097/multiclass-image-classification-using-cnn
#https://www.tensorflow.org/tutorials/images/data_augmentation
#https://stackoverflow.com/questions/67503271/how-to-perform-data-augmentation-using-keras-and-tensorflows-imagedatagenerator
#https://www.datasnips.com/blog/2021/8/30/Image-Augmentation-Using-Keras-ImageDataGenerator-with-Tensorflow/
#https://www.tensorflow.org/tutorials/structured_data/imbalanced_data# for ROC 
#https://www.tensorflow.org/tutorials/structured_data/imbalanced_data# for class imbalance 
#https://towardsdatascience.com/what-is-a-tensor-processing-unit-tpu-and-how-does-it-work-dbbe6ecbd8ad# for TPU 
#https://www.pluralsight.com/guides/data-visualization-deep-learning-model-using-matplotlib# for test accuracy

# %%
import random
import cv2
from keras import backend as K
from keras.preprocessing import image
from sklearn.metrics import roc_auc_score, roc_curve
from tensorflow.compat.v1.logging import INFO, set_verbosity
#load images
def load_image(img, image_dir, df, preprocess=True, H=320, W=320):
    """Load and preprocess image."""
    img_path = image_dir + img
    mean, std = get_mean_std_per_batch(img_path, df, H=H, W=W)
    x = image.load_img(img_path, target_size=(H, W))
    if preprocess:
        x -= mean
        x /= std
        x = np.expand_dims(x, axis=0)
    return x

# %%
# !pip install -q efficientnet
import efficientnet.tfkeras as efn


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from keras.preprocessing.image import ImageDataGenerator
from keras.applications.densenet import DenseNet121
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model

from keras.models import load_model


# from tensorflow.keras.applications import DenseNet121
import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.optimizers import Adam
# import tensorflow.keras.layers as Layers

# %%
#using tpu 
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)

# %%
IMAGE_SIZE=[224,224]
BATCH_SIZE = 64

# %%
#importing dataset 
import pandas as pd 
train_df_main = pd.read_csv('train_df.csv')

train_df_main.drop(['No Finding'], axis = 1, inplace = True)
labels = train_df_main.columns[2:-1]
labels

# %%
from sklearn.model_selection import train_test_split

train_df, discard = train_test_split(train_df_main, test_size = 0.7, random_state = 1993)

# %%
#data leakage eg multiple patient overlaps
def check_for_leakage(df1, df2, patient_col):
    df1_patients_unique = set(df1[patient_col].values)
    df2_patients_unique = set(df2[patient_col].values)
    patients_in_both_groups = df1_patients_unique.intersection(df2_patients_unique)
    # leakage contains true if there is patient overlap, otherwise false.
    leakage = len(patients_in_both_groups)>0 
    return leakage

# %%
def get_train_generator(df, image_dir, x_col, y_cols, shuffle=True, batch_size=8, seed=1, target_w = 320, target_h = 320):
   
    print("getting train generator...")
    # normalize images
    image_generator = ImageDataGenerator(
        samplewise_center=True,
        samplewise_std_normalization= True, 
        shear_range=0.1,
        zoom_range=0.15,
        rotation_range=5,
        width_shift_range=0.1,
        height_shift_range=0.05,
        horizontal_flip=True, 
        vertical_flip = False, 
        rescale=1.0/255.0,
        fill_mode = 'reflect')
    
    
    # flow from directory with specified batch size
    # and target image size
    generator = image_generator.flow_from_dataframe(
            dataframe=df,
            directory=None,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            shuffle=shuffle,
            seed=seed,
            target_size=(target_w,target_h))
    
    return generator

# %%
train_generator = get_train_generator(df = train_set,
                                      image_dir = None, 
                                      x_col = "FilePath",
                                      y_cols = labels, 
                                      batch_size=BATCH_SIZE,
                                      target_w = IMAGE_SIZE[0], 
                                      target_h = IMAGE_SIZE[1] 
                                      )

# %%
#visualizing images
def get_label(y):
    ret_labels = []
    i = 0
    for idx in y:
        if idx:
            ret_labels.append(labels[i])
        i += 1
    if not ret_labels:
        return 'No Label'
    else:
        return '|'.join(ret_labels)

#get one batch of images from the imageset    
x, y = train_generator.__getitem__(0)



#show a set of images along with the labels appended at the top as title.
fig=plt.figure(figsize=(20, 10))
columns = 4; rows =2 
for i in tqdm(range(1, columns*rows +1)):
    fig.add_subplot(rows, columns, i)
    plt.imshow(x[i-1], cmap = 'gray')
    plt.title(get_label(y[i-1]))
    plt.axis(False)
    fig.add_subplot

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Concatenate, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# %%
with strategy.scope():
  
    def conv_block(x, growth_rate):
        x1 = BatchNormalization()(x)
        x1 = ReLU()(x1)
        x1 = Conv2D(filters=growth_rate, kernel_size=(3, 3), padding='same')(x1)
        x = Concatenate()([x, x1])
        return x

    def dense_block(x, num_layers, growth_rate):
        for _ in range(num_layers):
            x = conv_block(x, growth_rate)
        return x

    def transition_block(x, reduction):
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(int(tf.keras.backend.int_shape(x)[-1] * reduction), kernel_size=(1, 1), padding='same')(x)
        x = tf.keras.layers.AveragePooling2D((2, 2), strides=(2, 2))(x)
        return x

    def final_diseases_detection_model(input_shape=(224, 224, 3), num_classes=1000, growth_rate=32, num_blocks=[6, 12, 24, 16], reduction=0.5):
        inputs = Input(shape=input_shape)
        x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

        num_features = 64
        for i, num_layers in enumerate(num_blocks):
            x = dense_block(x, num_layers, growth_rate)
            num_features += num_layers * growth_rate
            if i != len(num_blocks) - 1:
                x = transition_block(x, reduction)

        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = GlobalAveragePooling2D()(x)
        x = Dense(num_classes, activation='softmax')(x)

        model = Model(inputs, x, name='final_diseases_detection_model')
        return model
    model = final_diseases_detection_model(input_shape = (224,224,3),num_classes=len(labels))
    
model.compile(
    optimizer=tf.keras.optimizers.Adam( learning_rate=1e-4, amsgrad=False), 
    loss = 'binary_crossentropy',
    metrics = ['binary_accuracy']
)

model.summary()

# %%
checkpoint = ModelCheckpoint(
    'best_weights.h5',
    monitor='val_accuracy',  # Metric to monitor
    verbose=1,
    save_best_only=True,
    mode='max'  # Mode of the monitored metric (e.g., max for accuracy, min for loss)
)

# %%
def build_lrfn(lr_start=0.002, lr_max=0.010, 
               lr_min=0, lr_rampup_epochs=8, 
               lr_sustain_epochs=0, lr_exp_decay=.8):

    def lrfn(epoch):
        if epoch < lr_rampup_epochs:
            lr = (lr_max - lr_start) / lr_rampup_epochs * epoch + lr_start
        elif epoch < lr_rampup_epochs + lr_sustain_epochs:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) *\
                 lr_exp_decay**(epoch - lr_rampup_epochs\
                                - lr_sustain_epochs) + lr_min
        return lr
    return lrfn

lrfn = build_lrfn()
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
# Import the compute_class_weight function
from sklearn.utils import class_weight

# Calculate the class weights for each class
class_weights = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)

# Convert the class weights to a dictionary
class_weights = dict(enumerate(class_weights))

# Train your model with the class weights
history = model.fit_generator(train_generator, 
                              validation_data=valid_generator,
                              steps_per_epoch=len(train_generator),  
                              epochs = 30,
                              callbacks=[checkpoint,lr_schedule],
                              class_weight=class_weights 
                             )

# Print the model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from sklearn.utils import class_weight
#       4 # Calculate the class weights for each class
# ----> 5 class_weights = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
#       7 # Convert the class weights to a dictionary
#       8 class_weights = dict(enumerate(class_weights))
#
# NameError: name 'np' is not defined

# %%
def visualize_training(history, lw = 3):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['binary_accuracy'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_binary_accuracy'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Training Accuracy vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(fontsize = 'x-large')
    plt.show()

    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_loss'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Training Loss vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(fontsize = 'x-large')
    plt.show()
visualize_training(history)

# %%
predicted_vals = model.predict_generator(test_generator, steps = len(test_generator))
auc_rocs_before =get_roc_curve(labels, predicted_vals, test_generator, when = 'before training')

# %%
model.save_weights('final_diseases_detection_model_weight.h5')

# %%
train_df

# %%
model.load_weights("final_diseases_detection_model_weight.h5")

# %%
model = tf.keras.models.load_model("final_diseases_detection_model.h5")

# %%
import cv2
import numpy as np
import tensorflow as tf

# Load your PNG image
image_path = '00016051_011.png'  # Replace with the path to your PNG image
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Ensure the image is in RGB format

# Resize the image to 224x224 to match the model's input shape
image = cv2.resize(image, (224, 224))

image = image / 255.0  # Normalize pixel values to [0, 1]

# Make a prediction using your model
prediction = model.predict(np.expand_dims(image, axis=0))  # Add an extra dimension for batch size

# Get the predicted class label and associated probability/confidence
predicted_label = np.argmax(prediction)
confidence = prediction[0][predicted_label]  # Probability of the predicted class

# If you want to map the class index to a class name
class_names = ["Atelectasis","Cardiomegaly","Consolidation","Edema","Effusion","Emphysema","Fibrosis","Hernia","Infiltration","Mass","Nodule","Pleural_Thickening","Pneumonia","Pneumothorax"]
predicted_class_name = class_names[predicted_label-1]

# Now 'predicted_class_name' contains the predicted class name for the single image,
# and 'confidence' contains the associated confidence.
print(f'Predicted Class: {predicted_class_name}')
print(f'Confidence: {confidence * 100:.2f}%')
# Out:
# 1/1 [==============================] - 0s 243ms/step
# Predicted Class: Effusion
# Confidence: 20.82%

# %%
# Import the necessary modules
import tensorflow as tf
from tensorflow import keras
import os
# Define the image size and the batch size
IMG_SIZE = 224
BATCH_SIZE = 32
# Create a data generator that rescales the pixel values to [0, 1] range
data_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# Load the images from a test directory and create a test dataset
test_ds = data_gen.flow_from_directory(
    directory="D:/TAHAB WORKING FOLDER/hi/images",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
results = model.evaluate(test_ds)
print("Test loss:", results[0])
print("Test accuracy:", results[1])

# %%
import tensorflow as tf

# %%
# Load the model from the file my_model.h5
model = tf.keras.models.load_model("final_diseases_detection_model.h5")

# %%
model.summary()
# Out:
# Model: "final_diseases_detection_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 32)   18464       ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 96)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 56, 56, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   27680       ['re_lu_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 32)   36896       ['re_lu_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 160)  0           ['concatenate_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 160)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   46112       ['re_lu_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 192)  0           ['concatenate_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 192)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   55328       ['re_lu_5[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 224)  0           ['concatenate_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 224)  896        ['concatenate_4[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 224)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   64544       ['re_lu_6[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 256)  0           ['concatenate_4[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 256)  1024       ['concatenate_5[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  32896       ['re_lu_7[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 128)  0          ['conv2d_7[0][0]']
#  ing2D)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['average_pooling2d[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 28, 28, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   36896       ['re_lu_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 160)  0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 160)  640        ['concatenate_6[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 28, 28, 160)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   46112       ['re_lu_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 192)  0           ['concatenate_6[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 192)  768        ['concatenate_7[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   55328       ['re_lu_10[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 224)  0           ['concatenate_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 224)  896        ['concatenate_8[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 28, 28, 224)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   64544       ['re_lu_11[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 256)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 256)  1024       ['concatenate_9[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 28, 28, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   73760       ['re_lu_12[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 288)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 288)  1152       ['concatenate_10[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 28, 28, 288)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   82976       ['re_lu_13[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 320)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 320)  1280       ['concatenate_11[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 28, 28, 320)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   92192       ['re_lu_14[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 352)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 352)  1408       ['concatenate_12[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 28, 28, 352)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   101408      ['re_lu_15[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 28, 28, 384)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 384)  1536       ['concatenate_13[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 28, 28, 384)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   110624      ['re_lu_16[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 28, 28, 416)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 416)  1664       ['concatenate_14[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 28, 28, 416)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   119840      ['re_lu_17[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 28, 28, 448)  0           ['concatenate_14[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 448)  1792       ['concatenate_15[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 28, 28, 448)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 32)   129056      ['re_lu_18[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 480)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 480)  1920       ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 28, 28, 480)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   138272      ['re_lu_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 512)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 256)  131328      ['re_lu_20[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 256)  0          ['conv2d_20[0][0]']
#  oling2D)
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 32)   73760       ['re_lu_21[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 288)  0           ['average_pooling2d_1[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 288)  1152       ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 14, 14, 288)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 32)   82976       ['re_lu_22[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 320)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 320)  1280       ['concatenate_19[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 14, 14, 320)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 32)   92192       ['re_lu_23[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 352)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 352)  1408       ['concatenate_20[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 14, 14, 352)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 32)   101408      ['re_lu_24[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 384)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 384)  1536       ['concatenate_21[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 32)   110624      ['re_lu_25[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 416)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 416)  1664       ['concatenate_22[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 14, 14, 416)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 32)   119840      ['re_lu_26[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 448)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 448)  1792       ['concatenate_23[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 14, 14, 448)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 32)   129056      ['re_lu_27[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 480)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 480)  1920       ['concatenate_24[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 14, 14, 480)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 32)   138272      ['re_lu_28[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 512)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 512)  2048       ['concatenate_25[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 14, 14, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 32)   147488      ['re_lu_29[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 14, 14, 544)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 544)  2176       ['concatenate_26[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 14, 14, 544)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 32)   156704      ['re_lu_30[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 14, 14, 576)  0           ['concatenate_26[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 576)  2304       ['concatenate_27[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 14, 14, 576)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 32)   165920      ['re_lu_31[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 14, 14, 608)  0           ['concatenate_27[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 608)  2432       ['concatenate_28[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 14, 14, 608)  0           ['batch_normalization_32[0][0]']
#  conv2d_32 (Conv2D)             (None, 14, 14, 32)   175136      ['re_lu_32[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 14, 14, 640)  0           ['concatenate_28[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 640)  2560       ['concatenate_29[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 14, 14, 640)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 32)   184352      ['re_lu_33[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 14, 14, 672)  0           ['concatenate_29[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 672)  2688       ['concatenate_30[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 14, 14, 672)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 32)   193568      ['re_lu_34[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 14, 14, 704)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 704)  2816       ['concatenate_31[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 14, 14, 704)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 32)   202784      ['re_lu_35[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 14, 14, 736)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 736)  2944       ['concatenate_32[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 14, 14, 736)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   212000      ['re_lu_36[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 14, 14, 768)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 768)  3072       ['concatenate_33[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 14, 14, 768)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   221216      ['re_lu_37[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 14, 14, 800)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 800)  3200       ['concatenate_34[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 14, 14, 800)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 32)   230432      ['re_lu_38[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 14, 14, 832)  0           ['concatenate_34[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 832)  3328       ['concatenate_35[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 14, 14, 832)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 32)   239648      ['re_lu_39[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 14, 14, 864)  0           ['concatenate_35[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 864)  3456       ['concatenate_36[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 14, 14, 864)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 32)   248864      ['re_lu_40[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 14, 14, 896)  0           ['concatenate_36[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 896)  3584       ['concatenate_37[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 14, 14, 896)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 32)   258080      ['re_lu_41[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 14, 14, 928)  0           ['concatenate_37[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 928)  3712       ['concatenate_38[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 14, 14, 928)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   267296      ['re_lu_42[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 14, 14, 960)  0           ['concatenate_38[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 960)  3840       ['concatenate_39[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 14, 14, 960)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 32)   276512      ['re_lu_43[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 14, 14, 992)  0           ['concatenate_39[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 992)  3968       ['concatenate_40[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 14, 14, 992)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   285728      ['re_lu_44[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 14, 14, 1024  0           ['concatenate_40[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 1024  4096       ['concatenate_41[0][0]']
#  ormalization)                  )
#
#  re_lu_45 (ReLU)                (None, 14, 14, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 512)  524800      ['re_lu_45[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 512)   0           ['conv2d_45[0][0]']
#  oling2D)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 512)   2048        ['average_pooling2d_2[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 32)     147488      ['re_lu_46[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 7, 7, 544)    0           ['average_pooling2d_2[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 544)   2176        ['concatenate_42[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 7, 7, 544)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 32)     156704      ['re_lu_47[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 7, 7, 576)    0           ['concatenate_42[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 576)   2304        ['concatenate_43[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 7, 7, 576)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     165920      ['re_lu_48[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 7, 7, 608)    0           ['concatenate_43[0][0]',
#                                                                   'conv2d_48[0][0]']
#  batch_normalization_49 (BatchN  (None, 7, 7, 608)   2432        ['concatenate_44[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 7, 7, 608)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 32)     175136      ['re_lu_49[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 7, 7, 640)    0           ['concatenate_44[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 640)   2560        ['concatenate_45[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 7, 7, 640)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     184352      ['re_lu_50[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 7, 7, 672)    0           ['concatenate_45[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 672)   2688        ['concatenate_46[0][0]']
#  ormalization)
#
#  re_lu_51 (ReLU)                (None, 7, 7, 672)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 32)     193568      ['re_lu_51[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 7, 7, 704)    0           ['concatenate_46[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 704)   2816        ['concatenate_47[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 7, 7, 704)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 32)     202784      ['re_lu_52[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 7, 7, 736)    0           ['concatenate_47[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 736)   2944        ['concatenate_48[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 7, 7, 736)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 32)     212000      ['re_lu_53[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 7, 7, 768)    0           ['concatenate_48[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 768)   3072        ['concatenate_49[0][0]']
#  ormalization)
#
#  re_lu_54 (ReLU)                (None, 7, 7, 768)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 32)     221216      ['re_lu_54[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 7, 7, 800)    0           ['concatenate_49[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 800)   3200        ['concatenate_50[0][0]']
#  ormalization)
#
#  re_lu_55 (ReLU)                (None, 7, 7, 800)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 32)     230432      ['re_lu_55[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 7, 832)    0           ['concatenate_50[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 832)   3328        ['concatenate_51[0][0]']
#  ormalization)
#
#  re_lu_56 (ReLU)                (None, 7, 7, 832)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 32)     239648      ['re_lu_56[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 7, 864)    0           ['concatenate_51[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 864)   3456        ['concatenate_52[0][0]']
#  ormalization)
#  re_lu_57 (ReLU)                (None, 7, 7, 864)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 32)     248864      ['re_lu_57[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 7, 896)    0           ['concatenate_52[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 7, 7, 896)   3584        ['concatenate_53[0][0]']
#  ormalization)
#
#  re_lu_58 (ReLU)                (None, 7, 7, 896)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 32)     258080      ['re_lu_58[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 7, 928)    0           ['concatenate_53[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 7, 7, 928)   3712        ['concatenate_54[0][0]']
#  ormalization)
#
#  re_lu_59 (ReLU)                (None, 7, 7, 928)    0           ['batch_normalization_59[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 32)     267296      ['re_lu_59[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 7, 960)    0           ['concatenate_54[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 960)   3840        ['concatenate_55[0][0]']
#  ormalization)
#
#  re_lu_60 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 32)     276512      ['re_lu_60[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 7, 992)    0           ['concatenate_55[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 992)   3968        ['concatenate_56[0][0]']
#  ormalization)
#
#  re_lu_61 (ReLU)                (None, 7, 7, 992)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 32)     285728      ['re_lu_61[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 7, 1024)   0           ['concatenate_56[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 1024)  4096        ['concatenate_57[0][0]']
#  ormalization)
#
#  re_lu_62 (ReLU)                (None, 7, 7, 1024)   0           ['batch_normalization_62[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['re_lu_62[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 14)           14350       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 9,930,062
# Trainable params: 9,861,262
# Non-trainable params: 68,800
# __________________________________________________________________________________________________
